# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('test.csv')
sf = pd.read_csv('IMDB-Dataset.csv')

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Count positive and negative reviews in each dataset
df_counts = df['sentiment'].value_counts()
sf_counts = sf['sentiment'].value_counts()

# Combine counts into a DataFrame for easier plotting
distribution = pd.DataFrame({
    'Dataset': ['df'] * 2 + ['sf'] * 2,
    'Sentiment': ['Positive', 'Negative'] * 2,
    'Count': [df_counts[1], df_counts[0], sf_counts[1], sf_counts[0]]
})

# Plot the bar graph
plt.figure(figsize=(8, 6))
sns.barplot(data=distribution, x='Dataset', y='Count', hue='Sentiment', palette='coolwarm')
plt.title('Sentiment Distribution in Datasets', fontsize=16)
plt.ylabel('Count', fontsize=12)
plt.xlabel('Dataset', fontsize=12)
plt.legend(title='Sentiment', fontsize=10)
plt.tight_layout()

# Save the plot as an image
plt.savefig("dataset_distribution.png")

# Show the plot
plt.show()
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_3660\3995991776.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'Count': [df_counts[1], df_counts[0], sf_counts[1], sf_counts[0]]

# %%
df.head()
# Out:
#                                               review sentiment
# 0  Starting  back at work today   Looks like it'l...  negative
# 1  Sugar levels dropping... munchies setting in. ...  positive
# 2      @karineb22 yeah!!! have a great summer break!  positive
# 3  hannah montana was very good.  now going to re...  positive
# 4  @Mayra326 aww, have fun!  I just had my 3D las...  positive

# %%
sf.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df['review'][0]
# Out:
# "Starting  back at work today   Looks like it'll be raining for the next couple of days"

# %%
sf['review'][0]
# Out:
# "One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />I would say the main appeal of the show is due to the 
# ...

# %% [markdown]
# Text Cleaning
# 1. Sample 10000 rows
# 2. Remove HTML tags
# 3. Remove special characters
# 4. Convert everything to lowercase
# 5. Remove stopwords
# 6. Stemming

# %%
df = df.sample(50000)

# %%
sf = sf.sample(50000)

# %%
df.shape
# Out:
# (50000, 2)

# %%
sf.shape
# Out:
# (50000, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50000 entries, 102196 to 96386
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 1.1+ MB

# %%
sf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50000 entries, 21172 to 15881
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 1.1+ MB

# %%
df['sentiment'].replace({'positive': 1, 'negative': 0}, inplace=True)
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_3660\4276536853.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['sentiment'].replace({'positive': 1, 'negative': 0}, inplace=True)
# ...

# %%
sf['sentiment'].replace({'positive': 1, 'negative': 0}, inplace=True)
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_3660\1675891007.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sf['sentiment'].replace({'positive': 1, 'negative': 0}, inplace=True)
# ...

# %%
df.head()
# Out:
#                                                    review  sentiment
# 102196  @jessicahume awe, yesss. Thats the only way to...          1
# 1757    bella my bella i miss my doggie  cant wait to ...          0
# 58070   That's is a good web site  http://www.albumwas...          1
# 10154   Ok gotta stop tweetin and start sleepin lol go...          0
# 34356   @janoda Thank you! But either way, I'm just ha...          1

# %%
sf.head()
# Out:
#                                                   review  sentiment
# 21172  Well, I do like the gore in this movie - it is...          0
# 21210  I agree with the posters before that the chara...          1
# 44877  No music. No stupid masala. A reasonably reali...          1
# 31090  I love the absurdity and biting humor of Buñue...          1
# 4343   I've seen this film several times in a variety...          0

# %%
import re
clean = re.compile('<.*?>')
re.sub(clean, '', sf.iloc[2]['review'])
# Out:
# 'No music. No stupid masala. A reasonably realistic portrayal of the police system in India and based on a real "encounter" specialist in India, Daya Nayak. That is Ab Tak 56 (56 symbolises how many criminals the lead "Sadhu Agashe" has killed" - well you already know that bit)Brilliance exudes Nan Patekar in the role as a relaxed and calculating Indian cop. THe one liners are just hilarious. The plot though slightly predictable on review, is intriguing all the same. Another one of the films from Ram Gopal Vermas The Factory. Movies which are either decent or really good, Ab Tak CHappan meanders close to very good. But yet remains one of the Top 70 films released from India, commercial and artsy included.What is great is the story telling is relaxed and showcases finally (in an Indian flick) how the police network works. The cast is really damn good but seriously the one liners are funny as hell (though i dont know if the subtitled version will appear as funny) The producers are tryi
# ...

# %%
import re
clean = re.compile('<.*?>')
re.sub(clean, '', df.iloc[2]['review'])
# Out:
# "That's is a good web site  http://www.albumwash.com/"

# %%
def clean_html(text):
    clean = re.compile('<.*?>')
    return re.sub(clean, '', text)

# %%
df['review'] = df['review'].apply(clean_html)

# %%
sf['review'] = sf['review'].apply(clean_html)

# %%
def convert_lower(text):
    return text.lower()

# %%
df['review'] = df['review'].apply(convert_lower)

# %%
sf['review'] = sf['review'].apply(convert_lower)

# %%
def remove_special(text):
    x = ''
    for i in text:
        if i.isalnum() or i == ' ':
            x += i
    return x

# %%
remove_special(
	'More of a near miss than a flop, MR. IMPERIUM stars Ezio Pinza as Alex, heir apparent to and later king of a small European nation, '
	'who falls in love with a willing American actress and entertainer, Fredda Barlo (Lana Turner), but due to machinations by the sly prime minister '
	'of Alex as king, nicely played by Cedric Hardwicke, the lovers are separated for 12 years before being reunited in Palm Springs where their love '
	'is rekindled. Director Don Hartman, who also scripts, is not able to fully utilize his talent for snappy dialogue because of Pinza\'s tentative English '
	'usage, and the requisite rewriting, coupled with less than total rapport in evidence between the two stars, results in a somewhat raggedy tone to the screenplay, '
	'exacerbated by the studio\'s unkind cutting of many scenes, leading to a confusing ending. The overpowering Pinza dominates his scenes with Turner, but both performers '
	'score with good work, while Marjorie Main is impressive with her patter effects as written, with Debbie Reynolds placed on track by Louis B. Mayer for SINGIN\' IN THE RAIN '
	'as a result of her sprightly performance here; only Barry Sullivan is heavily victimized by the flagrant cutting. Prettily filmed largely in Pebble Beach, California, and other '
	'Monterey County environs, the film is endowed with Pinza\'s iron strong operatic basso in Solamente Una Vez, as well as with original songs by Harold Arlen and Dorothy Fields, '
	'with Douglas Shearer splendidly handling the sound recording, and notice must be made of the fine set decorations by Edwin Willis, and the effective costume designs by Walter Plunkett.'
)
# Out:
# 'More of a near miss than a flop MR IMPERIUM stars Ezio Pinza as Alex heir apparent to and later king of a small European nation who falls in love with a willing American actress and entertainer Fredda Barlo Lana Turner but due to machinations by the sly prime minister of Alex as king nicely played by Cedric Hardwicke the lovers are separated for 12 years before being reunited in Palm Springs where their love is rekindled Director Don Hartman who also scripts is not able to fully utilize his talent for snappy dialogue because of Pinzas tentative English usage and the requisite rewriting coupled with less than total rapport in evidence between the two stars results in a somewhat raggedy tone to the screenplay exacerbated by the studios unkind cutting of many scenes leading to a confusing ending The overpowering Pinza dominates his scenes with Turner but both performers score with good work while Marjorie Main is impressive with her patter effects as written with Debbie Reynolds placed
# ...

# %%
df['review'] = df['review'].apply(remove_special)

# %%
sf['review'] = sf['review'].apply(convert_lower)

# %%
from nltk.corpus import stopwords

# %%
sf
# Out:
#                                                   review  sentiment
# 21172  well, i do like the gore in this movie - it is...          0
# 21210  i agree with the posters before that the chara...          1
# 44877  no music. no stupid masala. a reasonably reali...          1
# 31090  i love the absurdity and biting humor of buñue...          1
# 4343   i've seen this film several times in a variety...          0
# ...                                                  ...        ...
# 21675  the original with barbara stanwyk is saved onl...          1
# 18845  after a while i realized it was just my iq slo...          0
# 41089  well, if you set aside the fact that this movi...          0
# 20147  here we go with other slasher movie, good look...          0
# 15881  i really liked this movie, and went back to se...          1
#
# [50000 rows x 2 columns]

# %%
df
# Out:
#                                                    review  sentiment
# 102196  jessicahume awe yesss thats the only way to ge...          1
# 1757    bella my bella i miss my doggie  cant wait to ...          0
# 58070       thats is a good web site  httpwwwalbumwashcom          1
# 10154   ok gotta stop tweetin and start sleepin lol go...          0
# 34356   janoda thank you but either way im just happy ...          1
# ...                                                   ...        ...
# 93352   allergydad lol  ive got a fridge full of the s...          0
# 97357                    srjoser you never bbm me no more          0
# 89711          wow i just slept till 2pmagain good job me          0
# 84836                         najicaloves im here until 8          1
# 96386   i dont want to in back to fl yet i want to sta...          0
#
# [50000 rows x 2 columns]

# %%
def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    return ' '.join(word for word in text.split() if word not in stop_words)

# %%
df['review'] = df['review'].apply(remove_stopwords)

# %%
sf['review'] = sf['review'].apply(remove_stopwords)

# %%
df
# Out:
#                                                    review  sentiment
# 102196           jessicahume awe yesss thats way get done          1
# 1757    bella bella miss doggie cant wait get home pla...          0
# 58070             thats good web site httpwwwalbumwashcom          1
# 10154   ok gotta stop tweetin start sleepin lol got an...          0
# 34356               janoda thank either way im happy plug          1
# ...                                                   ...        ...
# 93352   allergydad lol ive got fridge full stuff revie...          0
# 97357                                   srjoser never bbm          0
# 89711                    wow slept till 2pmagain good job          0
# 84836                                    najicaloves im 8          1
# 96386         dont want back fl yet want stay bama longer          0
#
# [50000 rows x 2 columns]

# %%
sf
# Out:
#                                                   review  sentiment
# 21172  well, like gore movie - genuingly unsetteling....          0
# 21210  agree posters characters exceptionally strong ...          1
# 44877  music. stupid masala. reasonably realistic por...          1
# 31090  love absurdity biting humor buñuel's surrealis...          1
# 4343   i've seen film several times variety short-fil...          0
# ...                                                  ...        ...
# 21675  original barbara stanwyk saved stanwyk's perfo...          1
# 18845  realized iq slowly dropping. frostbite one pat...          0
# 41089  well, set aside fact movie features abysmal ac...          0
# 20147  go slasher movie, good looking people acting e...          0
# 15881  really liked movie, went back see two times wi...          1
#
# [50000 rows x 2 columns]

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem_words(text):
    return [ps.stem(word) for word in text.split()]

# %%
df['review'] = df['review'].apply(stem_words)

# %%
sf['review'] = sf['review'].apply(stem_words)

# %%
df
# Out:
#                                                    review  sentiment
# 102196     [jessicahum, awe, yesss, that, way, get, done]          1
# 1757    [bella, bella, miss, doggi, cant, wait, get, h...          0
# 58070        [that, good, web, site, httpwwwalbumwashcom]          1
# 10154   [ok, gotta, stop, tweetin, start, sleepin, lol...          0
# 34356       [janoda, thank, either, way, im, happi, plug]          1
# ...                                                   ...        ...
# 93352   [allergydad, lol, ive, got, fridg, full, stuff...          0
# 97357                               [srjoser, never, bbm]          0
# 89711             [wow, slept, till, 2pmagain, good, job]          0
# 84836                                  [najicalov, im, 8]          1
# 96386   [dont, want, back, fl, yet, want, stay, bama, ...          0
#
# [50000 rows x 2 columns]

# %%
sf
# Out:
#                                                   review  sentiment
# 21172  [well,, like, gore, movi, -, genuingli, unsett...          0
# 21210  [agre, poster, charact, except, strong, believ...          1
# 44877  [music., stupid, masala., reason, realist, por...          1
# 31090  [love, absurd, bite, humor, buñuel', surrealis...          1
# 4343   [i'v, seen, film, sever, time, varieti, short-...          0
# ...                                                  ...        ...
# 21675  [origin, barbara, stanwyk, save, stanwyk', per...          1
# 18845  [realiz, iq, slowli, dropping., frostbit, one,...          0
# 41089  [well,, set, asid, fact, movi, featur, abysm, ...          0
# 20147  [go, slasher, movie,, good, look, peopl, act, ...          0
# 15881  [realli, like, movie,, went, back, see, two, t...          1
#
# [50000 rows x 2 columns]

# %%
def join_back(list_input):
    return ' '.join(list_input)

# %%
df['review'] = df['review'].apply(join_back)

# %%
sf['review'] = sf['review'].apply(join_back)

# %%
df
# Out:
#                                                    review  sentiment
# 102196             jessicahum awe yesss that way get done          1
# 1757    bella bella miss doggi cant wait get home play...          0
# 58070              that good web site httpwwwalbumwashcom          1
# 10154   ok gotta stop tweetin start sleepin lol got an...          0
# 34356               janoda thank either way im happi plug          1
# ...                                                   ...        ...
# 93352   allergydad lol ive got fridg full stuff review...          0
# 97357                                   srjoser never bbm          0
# 89711                    wow slept till 2pmagain good job          0
# 84836                                      najicalov im 8          1
# 96386         dont want back fl yet want stay bama longer          0
#
# [50000 rows x 2 columns]

# %%
sf
# Out:
#                                                   review  sentiment
# 21172  well, like gore movi - genuingli unsetteling. ...          0
# 21210  agre poster charact except strong believ actor...          1
# 44877  music. stupid masala. reason realist portray p...          1
# 31090  love absurd bite humor buñuel' surrealist film...          1
# 4343   i'v seen film sever time varieti short-film fe...          0
# ...                                                  ...        ...
# 21675  origin barbara stanwyk save stanwyk' performan...          1
# 18845  realiz iq slowli dropping. frostbit one pathet...          0
# 41089  well, set asid fact movi featur abysm acting; ...          0
# 20147  go slasher movie, good look peopl act everyon ...          0
# 15881  realli like movie, went back see two time with...          1
#
# [50000 rows x 2 columns]

# %%
X = np.concatenate((df.iloc[:, 0:1].values, sf.iloc[:, 0:1].values), axis=0)

# %%
X.shape
# Out:
# (100000, 1)

# %%
# %pip install scikit-learn
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=10000)
# Out:
# ...
#
# ...

# %%
reviews_combined = pd.concat([df['review'], sf['review']])
X = cv.fit_transform(reviews_combined).toarray()

# %%
X.shape
# Out:
# (100000, 10000)

# %%
y = np.concatenate((df.iloc[:, -1].values, sf.iloc[:, -1].values), axis=0)

# %%
y.shape
# Out:
# (100000,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.shape
# Out:
# (80000, 10000)

# %%
X_test.shape
# Out:
# (20000, 10000)

# %%
y_train.shape
# Out:
# (80000,)

# %%
y_test.shape
# Out:
# (20000,)

# %%
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB

# %%
clf1 = GaussianNB()
clf2 = BernoulliNB()
clf3 = MultinomialNB()

# %%
clf1.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
clf2.fit(X_train, y_train)
# Out:
# BernoulliNB()

# %%
clf3.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
y_pred1 = clf1.predict(X_test)
y_pred2 = clf2.predict(X_test)
y_pred3 = clf3.predict(X_test)

# %%
y_test.shape
# Out:
# (20000,)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score

# %%
print("Gaussian",accuracy_score(y_test, y_pred1))
print("Bernoulli",accuracy_score(y_test, y_pred2))
print("Multinomial",accuracy_score(y_test, y_pred3))
print("G", r2_score(y_test, y_pred1))
print("B", r2_score(y_test, y_pred2))
print("M", r2_score(y_test, y_pred3))
# Out:
# Gaussian 0.6418
# Bernoulli 0.76605
# Multinomial 0.76095
# G -0.4328963479504362
# B 0.06413707257676016
# M 0.04373570078852107

# %%
from xgboost import XGBClassifier

xgb_clf = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
xgb_clf.fit(X_train, y_train)
y_pred_xgb = xgb_clf.predict(X_test)


print("XGBoost Accuracy:", accuracy_score(y_test, y_pred_xgb))
# Out:
# c:\Users\adity\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning: [21:57:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost Accuracy: 0.7699

# %%
from sklearn.svm import LinearSVC

svm_clf = LinearSVC()
svm_clf.fit(X_train, y_train)
y_pred_svm = svm_clf.predict(X_test)

print("SVM Accuracy:", accuracy_score(y_test, y_pred_svm))
# Out:
# SVM Accuracy: 0.78215

# %%
from sklearn.ensemble import RandomForestClassifier

rf_clf = RandomForestClassifier(n_estimators=100)
rf_clf.fit(X_train, y_train)
y_pred_rf = rf_clf.predict(X_test)

print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 0.78915

# %%
from sklearn.linear_model import LogisticRegression

lr_clf = LogisticRegression(max_iter=1000)
lr_clf.fit(X_train, y_train)
y_pred_lr = lr_clf.predict(X_test)

print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred_lr))
# Out:
# Logistic Regression Accuracy: 0.79465

# %%
from sklearn.neural_network import MLPClassifier

mlp_clf = MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=500)
mlp_clf.fit(X_train, y_train)
y_pred_mlp = mlp_clf.predict(X_test)

print("MLP Classifier Accuracy:", accuracy_score(y_test, y_pred_mlp))
# Out:
# MLP Classifier Accuracy: 0.7839

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.14.1

# %%
# Sample random review
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import mode

# Assuming you have a list of 100 reviews
reviews = [
    "The movie was amazing, a masterpiece!", "Horrible acting, couldn't stand it.", 
    "The plot was weak but the visuals were stunning.", "An enjoyable film with great performances.", 
    "Not worth the hype, very disappointing.", "Absolutely loved it, will watch again.", 
    "The pacing was terrible, and the story was predictable.", "A delightful experience, thoroughly entertaining.", 
    "Mediocre at best, didn't live up to expectations.", "Fantastic movie, well-directed and engaging.", 
    
    "Too slow and boring, wouldn't recommend.", "The soundtrack was incredible, loved every minute.", 
    "Unoriginal script, felt like I've seen it before.", "Beautiful cinematography and a touching story.", 
    "A complete disaster, worst movie of the year.", "The characters were well-written and relatable.", 
    "Had some good moments but overall, not great.", "Breathtaking visuals and a gripping narrative.", 
    "Too many plot holes, left me frustrated.", "A perfect blend of action, drama, and humor.", 
    
    "The lead actor delivered a phenomenal performance.", "Predictable and uninteresting.", 
    "Kept me on the edge of my seat, brilliant thriller.", "Disjointed and hard to follow.", 
    "Heartwarming and inspiring, loved it.", "Overrated and full of clichés.", 
    "The twists and turns were exciting and unexpected.", "Fell asleep halfway through, so boring.", 
    "A fun and light-hearted comedy.", "Dark, intense, and very well executed.", 
    
    "The chemistry between the leads was amazing.", "Terrible CGI ruined the experience.", 
    "One of the best movies I've seen in a long time.", "The dialogue was cheesy and unrealistic.", 
    "Highly entertaining, a must-watch.", "The ending was abrupt and unsatisfying.", 
    "Brilliant direction and top-notch acting.", "The story lacked depth and emotion.", 
    "Couldn't stop laughing, absolutely hilarious.", "Full of suspense, kept me guessing until the end.", 
    
    "The visuals were stunning but the story was dull.", "A timeless classic, beautifully made.", 
    "Waste of time and money.", "Well-written script and strong performances.", 
    "Too long and dragged in places.", "The action sequences were mind-blowing.", 
    "Left me in tears, so emotional.", "Completely overrated, didn't enjoy it at all.", 
    "The cast did an excellent job.", "Confusing and all over the place.", 
    
    "A powerful and thought-provoking film.", "Not engaging, felt like a chore to watch.", 
    "The humor was spot-on and refreshing.", "The director's vision was truly remarkable.", 
    "Nothing special, just another generic movie.", "The movie had a great message.", 
    "Slow start but picked up towards the end.", "A visual treat, every frame was beautiful.", 
    "One of the worst movies I've ever seen.", "Exceeded my expectations, absolutely brilliant.", 
    
    "The ending was perfect and very satisfying.", "Ridiculous and far-fetched.", 
    "The lead actress was phenomenal.", "Disappointing sequel to a great first movie.", 
    "Captivating and beautifully shot.", "The jokes felt forced and awkward.", 
    "A gripping tale of love and loss.", "Flat characters and a predictable plot.", 
    "A rollercoaster of emotions, truly unforgettable.", "Failed to deliver on its promise.", 
    
    "A great watch for the whole family.", "Too much focus on visuals, weak storyline.", 
    "The romance was sweet and genuine.", "Cringeworthy and poorly made.", 
    "One of the year's best, highly recommended.", "Boring and overly long.", 
    "The animation was incredible, loved it!", "An inspiring story of perseverance.", 
    "Nothing memorable, pretty average.", "A thought-provoking and beautifully crafted film.", 
    
    "The villain was iconic, a true masterpiece.", "Poorly executed with no real direction.", 
    "Had me laughing and crying, a great mix of emotions.", "The pacing was just right, very engaging.", 
    "Cheap effects and bad acting ruined it.", "Every aspect of this movie was flawless.", 
    "Had potential but fell flat.", "The ending left me speechless.", 
    "Not as good as the trailer suggested.", "An absolute gem, will stay with me forever."
]


# Store results
results = []

# Process each review
for review in reviews:
    # Preprocess the review
    review_cleaned = clean_html(review)
    review_cleaned = convert_lower(review_cleaned)
    review_cleaned = remove_special(review_cleaned)
    review_cleaned = remove_stopwords(review_cleaned)
    review_cleaned = ' '.join(stem_words(review_cleaned))
    
    # Vectorize the review
    review_vectorized = cv.transform([review_cleaned]).toarray()
    
    # Predict the sentiment using all classifiers
    preds = [
        clf2.predict(review_vectorized)[0],
        clf3.predict(review_vectorized)[0],
        xgb_clf.predict(review_vectorized)[0],
        svm_clf.predict(review_vectorized)[0],
        mlp_clf.predict(review_vectorized)[0],
        lr_clf.predict(review_vectorized)[0],
        rf_clf.predict(review_vectorized)[0],
    ]

    print(preds)
    
    # Store the mode of predictions as the final sentiment
    majority_vote = mode(preds, keepdims=True).mode[0]  # Ensure it returns an array
    results.append(majority_vote)

    

# Calculate the number of positive and negative reviews
positive_count = results.count(1)  # Assuming 1 = Positive sentiment
negative_count = results.count(0)  # Assuming 0 = Negative sentiment

# Print results
print(f"Positive reviews: {positive_count}")
print(f"Negative reviews: {negative_count}")

# Plot the results
labels = ['Positive', 'Negative']
counts = [positive_count, negative_count]

plt.bar(labels, counts, color=['green', 'red'])
plt.title('Sentiment Analysis Results')
plt.ylabel('Number of Reviews')
plt.xlabel('Sentiment')
plt.show()
# Out:
# [np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1)]
# [np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0)]
# [np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0)]
# [np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1)]
# [np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(1)]
# [np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1)]
# [np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0)]
# [np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1)]
# [np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0)]
# [np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1)]
# ...

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Collect model performance data
results = {
    'Model': [
        'Naive Bayes (Bernoulli)', 
        'Naive Bayes (Multinomial)', 
        'XGBoost', 
        'SVM', 
        'Random Forest', 
        'Logistic Regression', 
        'MLP Classifier'
    ],
    'Accuracy': [
        accuracy_score(y_test, y_pred2),
        accuracy_score(y_test, y_pred3),
        accuracy_score(y_test, y_pred_xgb),
        accuracy_score(y_test, y_pred_svm),
        accuracy_score(y_test, y_pred_rf),
        accuracy_score(y_test, y_pred_lr),
        accuracy_score(y_test, y_pred_mlp)
    ]
}

# Step 2: Create a DataFrame
results_df = pd.DataFrame(results)

# Display the table
print(results_df)

# Step 3: Plot the comparison
plt.figure(figsize=(12, 6))
sns.barplot(data=results_df, x='Model', y='Accuracy', palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.title('Model Accuracy Comparison', fontsize=16)
plt.ylabel('Accuracy', fontsize=12)
plt.xlabel('Model', fontsize=12)
plt.tight_layout()

# Save the plot as an image
plt.savefig("model_comparison.png")

# Show the plot
plt.show()
# Out:
#                        Model  Accuracy
# 0    Naive Bayes (Bernoulli)   0.76605
# 1  Naive Bayes (Multinomial)   0.76095
# 2                    XGBoost   0.76990
# 3                        SVM   0.78215
# 4              Random Forest   0.78915
# 5        Logistic Regression   0.79465
# 6             MLP Classifier   0.78390
# C:\Users\adity\AppData\Local\Temp\ipykernel_3660\1079440802.py:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=results_df, x='Model', y='Accuracy', palette='viridis')

# %%
#import pickle

# Save models to pickle files
#pickle.dump(cv, open("count_vectorizer.pkl", "wb"))
#pickle.dump(clf1, open("naive_bayes_gaussian.pkl", "wb"))
#pickle.dump(clf2, open("naive_bayes_bernoulli.pkl", "wb"))
#pickle.dump(clf3, open("naive_bayes_multinomial.pkl", "wb"))
#pickle.dump(xgb_clf, open("xgboost.pkl", "wb"))
#pickle.dump(svm_clf, open("svm.pkl", "wb"))
#pickle.dump(rf_clf, open("random_forest.pkl", "wb"))
#pickle.dump(lr_clf, open("logistic_regression.pkl", "wb"))
#pickle.dump(mlp_clf, open("mlp.pkl", "wb"))

# %%
# Add word count column to both datasets
df['word_count'] = df['review'].apply(lambda x: len(x.split()))
sf['word_count'] = sf['review'].apply(lambda x: len(x.split()))

# Plot the distribution
plt.figure(figsize=(10, 6))
sns.kdeplot(df['word_count'], label='df Dataset', color='blue', shade=True)
sns.kdeplot(sf['word_count'], label='sf Dataset', color='red', shade=True)
plt.title('Word Count Distribution in Reviews', fontsize=16)
plt.xlabel('Word Count', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.legend()
plt.tight_layout()
plt.savefig("word_count_distribution.png")
plt.show()
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_3660\2965771045.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['word_count'], label='df Dataset', color='blue', shade=True)
# C:\Users\adity\AppData\Local\Temp\ipykernel_3660\2965771045.py:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(sf['word_count'], label='sf Dataset', color='red', shade=True)

# %%
# Pie chart for df dataset
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
df['sentiment'].value_counts().plot.pie(autopct='%1.1f%%', colors=['lightcoral', 'skyblue'], labels=['Negative', 'Positive'])
plt.title('Sentiment Proportion in df Dataset')

# Pie chart for sf dataset
plt.subplot(1, 2, 2)
sf['sentiment'].value_counts().plot.pie(autopct='%1.1f%%', colors=['lightcoral', 'skyblue'], labels=['Negative', 'Positive'])
plt.title('Sentiment Proportion in sf Dataset')

plt.tight_layout()
plt.savefig("sentiment_proportion_pie.png")
plt.show()

# %%
# Calculate average word count by sentiment
df_avg_word_count = df.groupby('sentiment')['word_count'].mean()
sf_avg_word_count = sf.groupby('sentiment')['word_count'].mean()

# Combine into a DataFrame
avg_word_count_df = pd.DataFrame({
    'Dataset': ['df', 'df', 'sf', 'sf'],
    'Sentiment': ['Positive', 'Negative'] * 2,
    'Average Word Count': [df_avg_word_count[1], df_avg_word_count[0], sf_avg_word_count[1], sf_avg_word_count[0]]
})

# Plot the bar graph
plt.figure(figsize=(8, 6))
sns.barplot(data=avg_word_count_df, x='Dataset', y='Average Word Count', hue='Sentiment', palette='coolwarm')
plt.title('Average Word Count by Sentiment', fontsize=16)
plt.ylabel('Average Word Count', fontsize=12)
plt.xlabel('Dataset', fontsize=12)
plt.legend(title='Sentiment', fontsize=10)
plt.tight_layout()
plt.savefig("average_word_count_by_sentiment.png")
plt.show()

# %%
# %pip install wordcloud
from collections import Counter
from wordcloud import WordCloud

# Combine positive and negative reviews separately
positive_reviews = ' '.join(df[df['sentiment'] == 1]['review'])
negative_reviews = ' '.join(df[df['sentiment'] == 0]['review'])

# Generate WordCloud
positive_wc = WordCloud(width=400, height=300, background_color='white').generate(positive_reviews)
negative_wc = WordCloud(width=400, height=300, background_color='white').generate(negative_reviews)

# Plot WordCloud
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.imshow(positive_wc, interpolation='bilinear')
plt.title('Positive Reviews WordCloud', fontsize=16)
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(negative_wc, interpolation='bilinear')
plt.title('Negative Reviews WordCloud', fontsize=16)
plt.axis('off')

plt.tight_layout()
plt.savefig("wordcloud_comparison.png")
plt.show()
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from collections import Counter
from wordcloud import WordCloud

# Combine positive and negative reviews separately
positive_reviews = ' '.join(df[df['sentiment'] == 1]['review'])
negative_reviews = ' '.join(df[df['sentiment'] == 0]['review'])

# Generate WordCloud
positive_wc = WordCloud(width=400, height=300, background_color='white').generate(positive_reviews)
negative_wc = WordCloud(width=400, height=300, background_color='white').generate(negative_reviews)

# Plot WordCloud
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.imshow(positive_wc, interpolation='bilinear')
plt.title('Positive Reviews WordCloud', fontsize=16)
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(negative_wc, interpolation='bilinear')
plt.title('Negative Reviews WordCloud', fontsize=16)
plt.axis('off')

plt.tight_layout()
plt.savefig("wordcloud_comparison2.png")
plt.show()

# %%
# Prepare accuracy scores
model_accuracies = {
    'Model': ['BernoulliNB', 'MultinomialNB', 'XGBoost', 'SVM', 'Random Forest', 'Logistic Regression', 'MLP'],
    'Accuracy': [
    
        accuracy_score(y_test, y_pred2),
        accuracy_score(y_test, y_pred3),
        accuracy_score(y_test, y_pred_xgb),
        accuracy_score(y_test, y_pred_svm),
        accuracy_score(y_test, y_pred_rf),
        accuracy_score(y_test, y_pred_lr),
        accuracy_score(y_test, y_pred_mlp)
    ]
}

# Convert to DataFrame
model_accuracy_df = pd.DataFrame(model_accuracies)

# Plot bar graph
plt.figure(figsize=(10, 6))
sns.barplot(data=model_accuracy_df, x='Model', y='Accuracy', palette='viridis')
plt.title('Model Accuracy Comparison', fontsize=16)
plt.xticks(rotation=45)
plt.ylabel('Accuracy', fontsize=12)
plt.xlabel('Model', fontsize=12)
plt.tight_layout()
plt.savefig("model_accuracy_comparison.png")
plt.show()
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_3660\989258524.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=model_accuracy_df, x='Model', y='Accuracy', palette='viridis')
